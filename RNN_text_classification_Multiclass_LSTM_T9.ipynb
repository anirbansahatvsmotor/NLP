# %%
from sklearn.metrics import precision_recall_curve, classification_report, confusion_matrix, roc_curve, roc_auc_score, precision_recall_fscore_support,auc
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense
from tensorflow.keras.utils import to_categorical
import keras
import tensorflow
from keras.layers import Dropout, BatchNormalization
import matplotlib.pyplot as plt
from sklearn.preprocessing import label_binarize
import seaborn as sns
import joblib



# Load your dataset
df = pd.read_csv("../DataSet/Commands_Classification_Dataset7.csv",encoding="latin1")  # Update with your dataset filename

# %%
df.head()
# Out:
#   Class Subclass SubclassCategory  \
# 0  Bike     Edge     Battery/Fuel
# 1  Bike     Edge     Battery/Fuel
# 2  Bike     Edge     Battery/Fuel
# 3  Bike     Edge     Battery/Fuel
# 4  Bike     Edge     Battery/Fuel
#
#                                             Commands              Response  \
# 0                  What is my current battery level?  Updating please wait
# 1       How much range do I have left on my battery?  Updating please wait
# 2     When was the last time my battery was charged?  Updating please wait
# 3        How long until my battery is fully charged?  Updating please wait
# 4  How long should I charge my vehicle for a suff...  Updating please wait
#
#    Label
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1

# %%
df['Subclass'].unique()
# Out:
# array(['Edge', 'Not needed', 'Cloud', 'Update'], dtype=object)

# %%
new_df = df[df['Subclass'] != 'Not needed'].reset_index(drop=True)
new_df
# Out:
#      Class Subclass SubclassCategory  \
# 0     Bike     Edge     Battery/Fuel
# 1     Bike     Edge     Battery/Fuel
# 2     Bike     Edge     Battery/Fuel
# 3     Bike     Edge     Battery/Fuel
# 4     Bike     Edge     Battery/Fuel
# ...    ...      ...              ...
# 1313  Bike   Update            Check
# 1314  Bike   Update            Check
# 1315  Bike   Update            Check
# 1316  Bike   Update            Check
# 1317  Bike     Edge            Basic
#
#                                                Commands  \
# 0                     What is my current battery level?
# 1          How much range do I have left on my battery?
# 2        When was the last time my battery was charged?
# 3           How long until my battery is fully charged?
# 4     How long should I charge my vehicle for a suff...
# ...                                                 ...
# 1313                Check for current available update
# 1314          Please check for current available update
# 1315                    Please check for current update
# 1316                        Check for available updates
# 1317  Activate bike's cruise control with speed limiter
#
#                                                Response  Label
# 0                                  Updating please wait      1
# 1                                  Updating please wait      1
# 2                                  Updating please wait      1
# 3                                  Updating please wait      1
# 4                                  Updating please wait      1
# ...                                                 ...    ...
# 1313                            Processing your command      1
# 1314                            Processing your command      1
# 1315                            Processing your command      1
# 1316                            Processing your command      1
# 1317  Utilize cruise control with speed limiter for ...      1
#
# [1318 rows x 6 columns]

# %%
new_df['Subclass'].unique()
# Out:
# array(['Edge', 'Cloud', 'Update'], dtype=object)

# %%
Y_Categorical=new_df['Subclass']
Y_Categorical
# Out:
# 0         Edge
# 1         Edge
# 2         Edge
# 3         Edge
# 4         Edge
#          ...
# 1313    Update
# 1314    Update
# 1315    Update
# 1316    Update
# 1317      Edge
# Name: Subclass, Length: 1318, dtype: object

# %%
# Count the unique values in the Y_Categorical column
unique_values_count = new_df['Subclass'].value_counts()

# Display the result
print(unique_values_count)
# Out:
# Subclass
# Edge      551
# Cloud     448
# Update    319
# Name: count, dtype: int64

# %%
len(new_df)
# Out:
# 1318

# %%
X=new_df['Commands']
X
# Out:
# 0                       What is my current battery level?
# 1            How much range do I have left on my battery?
# 2          When was the last time my battery was charged?
# 3             How long until my battery is fully charged?
# 4       How long should I charge my vehicle for a suff...
#                               ...
# 1313                  Check for current available update
# 1314            Please check for current available update
# 1315                      Please check for current update
# 1316                          Check for available updates
# 1317    Activate bike's cruise control with speed limiter
# Name: Commands, Length: 1318, dtype: object

# %%
# Automatically convert categorical values to labels
new_df['Subclass_Label'], _ = pd.factorize(new_df['Subclass'])
new_df['Subclass_Label']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1313    2
# 1314    2
# 1315    2
# 1316    2
# 1317    0
# Name: Subclass_Label, Length: 1318, dtype: int64

# %%
new_df
# Out:
#      Class Subclass SubclassCategory  \
# 0     Bike     Edge     Battery/Fuel
# 1     Bike     Edge     Battery/Fuel
# 2     Bike     Edge     Battery/Fuel
# 3     Bike     Edge     Battery/Fuel
# 4     Bike     Edge     Battery/Fuel
# ...    ...      ...              ...
# 1313  Bike   Update            Check
# 1314  Bike   Update            Check
# 1315  Bike   Update            Check
# 1316  Bike   Update            Check
# 1317  Bike     Edge            Basic
#
#                                                Commands  \
# 0                     What is my current battery level?
# 1          How much range do I have left on my battery?
# 2        When was the last time my battery was charged?
# 3           How long until my battery is fully charged?
# 4     How long should I charge my vehicle for a suff...
# ...                                                 ...
# 1313                Check for current available update
# 1314          Please check for current available update
# 1315                    Please check for current update
# 1316                        Check for available updates
# 1317  Activate bike's cruise control with speed limiter
#
#                                                Response  Label  Subclass_Label
# 0                                  Updating please wait      1               0
# 1                                  Updating please wait      1               0
# 2                                  Updating please wait      1               0
# 3                                  Updating please wait      1               0
# 4                                  Updating please wait      1               0
# ...                                                 ...    ...             ...
# 1313                            Processing your command      1               2
# 1314                            Processing your command      1               2
# 1315                            Processing your command      1               2
# 1316                            Processing your command      1               2
# 1317  Utilize cruise control with speed limiter for ...      1               0
#
# [1318 rows x 7 columns]

# %%
y=new_df['Subclass_Label']
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1313    2
# 1314    2
# 1315    2
# 1316    2
# 1317    0
# Name: Subclass_Label, Length: 1318, dtype: int64

# %%
y.unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
import numpy as np
import random
import tensorflow as tf
#7,17,2,
# Set the random seeds for reproducibility
def set_seed(seed=7):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Optionally, if using GPU, configure GPU settings to avoid non-determinism
def configure_gpu_memory_growth():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)

# Call these functions at the start of your code to ensure reproducibility
set_seed(7)  # Setting the seed for reproducibility
configure_gpu_memory_growth()  # Optionally manage GPU memory growth

# %%
def Main_Model(X, y, Y_Categorical):

    # Tokenize the text data
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(X)
    X_sequences = tokenizer.texts_to_sequences(X)

    # Padding sequences to make them of equal length
    max_sequence_length = max([len(seq) for seq in X_sequences])
    X_padded = pad_sequences(X_sequences, maxlen=max_sequence_length, padding='post')
    
    #print(y)
    print(Y_Categorical.unique())
    print(y.unique())

    # Convert labels to one-hot encoding
    y_encoded = to_categorical(y)    

    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42, stratify=y_encoded)

    # Define the RNN model for multiclass classification
    num_classes = len(np.unique(y))  # Number of unique classes
    model = Sequential()
    model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=500, input_length=max_sequence_length))
    model.add(LSTM(256, return_sequences=True))
    model.add(LSTM(128, return_sequences=True))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(32))
    model.add(Dense(num_classes, activation='softmax'))  # Use softmax activation for multiclass classification

    # Compile the model with categorical cross-entropy loss
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=15, batch_size=64, validation_data=(X_test, y_test))

    # Get and print training accuracy from history
    training_accuracy = history.history['accuracy'][-1]
    print("Training Accuracy:", training_accuracy)

    # Evaluate the model on test data
    loss, accuracy = model.evaluate(X_test, y_test)
    print("Test Loss:", loss)
    print("Test Accuracy:", accuracy)

    # Predicting the labels for test set
    y_pred = model.predict(X_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    y_test_classes = np.argmax(y_test, axis=1)

    # Classification report
    print("\nClassification Report:\n", classification_report(y_test_classes, y_pred_classes))
    
    
    # Assuming Y_Categorical is an array of the actual class names
    class_labels = Y_Categorical.unique()  # Get the unique class names

    # Confusion Matrix
    cm = confusion_matrix(y_test_classes, y_pred_classes)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',xticklabels=class_labels, yticklabels=class_labels)
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # ROC-AUC Curve (One-vs-Rest)
    y_test_bin = label_binarize(y_test_classes, classes=np.arange(num_classes))  # Binarize labels for ROC-AUC
    y_pred_bin = label_binarize(y_pred_classes, classes=np.arange(num_classes))
    
    # Calculate Precision, Recall, F1-Score
    precision, recall, f1, _ = precision_recall_fscore_support(y_test_classes, y_pred_classes, average='macro')
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")
    
    # Calculate AUC for each class
    roc_auc = roc_auc_score(y_test_bin, y_pred_bin, average='macro')
    print(f"ROC-AUC Score: {roc_auc}")

    # Plot ROC curves for each class
    fpr = dict()
    tpr = dict()
    roc_auc = dict()
    
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_bin[:, i])

    plt.figure(figsize=(10, 7))
    for i in range(num_classes):
        roc_auc[i] = auc(fpr[i], tpr[i])
        plt.plot(fpr[i], tpr[i], label=f'{class_labels[i]} (AUC = {roc_auc[i]:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Multiclass Classification')
    plt.legend(loc="lower right")
    plt.show()

    # Plot training and testing accuracy curves
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Testing Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend()
    plt.show()
    
    # Plot training and testing loss curves
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Testing Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.ylim([0, max(max(history.history['loss']), max(history.history['val_loss']))])
    plt.legend()
    plt.title('Loss Curve')
    plt.show()

    # Plot Precision-Recall (PR) curves for each class
    precision_dict = dict()
    recall_dict = dict()

    for i in range(num_classes):
        precision_dict[i], recall_dict[i], _ = precision_recall_curve(y_test_bin[:, i], y_pred_bin[:, i])

    plt.figure(figsize=(10, 7))
    for i in range(num_classes):
        plt.plot(recall_dict[i], precision_dict[i], label=f'{class_labels[i]}')
    
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve - Multiclass Classification')
    plt.legend(loc="lower left")
    plt.show()
    
    return tokenizer, model, max_sequence_length

# %%
# Function to predict the class of a command
def predict_class(command, tokenizer,model,max_sequence_length):
    sequence = tokenizer.texts_to_sequences([command])
    padded_sequence = pad_sequences(sequence, maxlen=max_sequence_length, padding='post')
    prediction = model.predict(padded_sequence)
    predicted_class_index = np.argmax(prediction)
    return predicted_class_index

# %%
tokenizer, model, max_sequence_length=Main_Model(X,y,Y_Categorical)
# Out:
# ['Edge' 'Cloud' 'Update']
# [0 1 2]
# C:\Users\anirban.saha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Epoch 1/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 19s 371ms/step - accuracy: 0.4039 - loss: 1.0617 - val_accuracy: 0.6136 - val_loss: 0.6775
# Epoch 2/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 263ms/step - accuracy: 0.8661 - loss: 0.4776 - val_accuracy: 0.9167 - val_loss: 0.2739
# Epoch 3/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 292ms/step - accuracy: 0.9481 - loss: 0.2242 - val_accuracy: 0.8939 - val_loss: 0.4280
# Epoch 4/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9636 - loss: 0.1648 - val_accuracy: 0.8409 - val_loss: 0.6009
# Epoch 5/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 272ms/step - accuracy: 0.9695 - loss: 0.1462 - val_accuracy: 0.9015 - val_loss: 0.4056
# Epoch 6/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 288ms/step - accuracy: 0.9712 - loss: 0.1541 - val_accuracy: 0.9242 - val_loss: 0.3436
# Epoch 7/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - accuracy: 0.9828 - loss: 0.0957 - val_accuracy: 0.9394 - val_loss: 0.2717
# Epoch 8/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 282ms/step - accuracy: 0.9851 - loss: 0.0745 - val_accuracy: 0.9280 - val_loss: 0.2377
# Epoch 9/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 285ms/step - accuracy: 0.9855 - loss: 0.0834 - val_accuracy: 0.9470 - val_loss: 0.2776
# Epoch 10/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.9880 - loss: 0.0591 - val_accuracy: 0.9508 - val_loss: 0.2422
# Epoch 11/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 290ms/step - accuracy: 0.9927 - loss: 0.0427 - val_accuracy: 0.9470 - val_loss: 0.2731
# Epoch 12/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 281ms/step - accuracy: 0.9927 - loss: 0.0408 - val_accuracy: 0.9508 - val_loss: 0.2623
# Epoch 13/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 269ms/step - accuracy: 0.9927 - loss: 0.0402 - val_accuracy: 0.9583 - val_loss: 0.2571
# Epoch 14/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 293ms/step - accuracy: 0.9927 - loss: 0.0403 - val_accuracy: 0.9583 - val_loss: 0.2610
# Epoch 15/15
# 17/17 ━━━━━━━━━━━━━━━━━━━━ 5s 289ms/step - accuracy: 0.9927 - loss: 0.0397 - val_accuracy: 0.9583 - val_loss: 0.2659
# Training Accuracy: 0.9914610981941223
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - accuracy: 0.9541 - loss: 0.2720
# Test Loss: 0.2659274637699127
# Test Accuracy: 0.9583333134651184
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 3s 226ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.93      0.96       110
#            1       0.92      0.98      0.95        90
#            2       0.97      0.98      0.98        64
#
#     accuracy                           0.96       264
#    macro avg       0.96      0.96      0.96       264
# weighted avg       0.96      0.96      0.96       264
# Precision: 0.96
# Recall: 0.96
# F1 Score: 0.96
# ROC-AUC Score: 0.9711591645104577

# %%
#y_encoded[11]
print(y.count())
print(y.unique())
# Out:
# 1318
# [0 1 2]

# %%
tokenizer

# %%
import joblib
# Assuming model is your trained model object
joblib.dump(model, './RNN_save_model/LSTM/MAINMODEL/RNN_Multiclass_Subclass.joblib')
joblib.dump(tokenizer, './RNN_save_model/LSTM/MAINMODEL/tokenizer.joblib')
joblib.dump(max_sequence_length, './RNN_save_model/LSTM/MAINMODEL/max_sequence_length_mainModel.joblib')
# Out:
# ['./RNN_save_model/LSTM/MAINMODEL/max_sequence_length_mainModel.joblib']

# %%
# # Example usage:
# command_input = input("Enter a command: ")
# print(command_input)
# prediction = predict_class(command_input)
# if(prediction==0):
#     print("Edge :", prediction)
# elif(prediction==1):
#     print("Cloud :", prediction)
# elif(prediction==2):
#     print("Update :",prediction)
# elif(prediction==3):
#     print("Miscellaneous :",prediction)
# else:
#     print("Dont know")

# %%
# Load your dataset
df_test = pd.read_csv("../DataSet/Comparision_AvsS.csv",encoding="latin1")  # Update with your dataset filename

# %%
df_test['Command']
# Out:
# 0                               Please check for update
# 1                         Please show me current update
# 2                            please perform bike update
# 3                     please kindly perform bike update
# 4              will I reach hyderabad with current fuel
# 5                                      Check for update
# 6                                Show me current update
# 7                                   perform bike update
# 8                            kindly perform bike update
# 9     Kindly tell me  whether will I reach hyderabad...
# 10            Is current fuel enough to reach Hyderabad
# 11                       Are my tyres pressure balanced
# 12                 Show me the fastest route to kolkata
# 13                   Will it rain tomorrow in bangaluru
# 14                  What is the weather status in delhi
# 15                        Play my playlist form spotify
# 16                                            Go to goa
# 17                                     Please go to goa
# 18                                       Take me to goa
# 19                     What is my current battery level
# 20                          Check my current fuel level
# 21                         Do I need to change the tyre
# 22                      Check tyre pressure and balance
# 23                   Check if tyre pressure is balanced
# 24                          what is current temperature
# 25              turn off the left indicator of the bike
# 26              turn on the right indicator of the bike
# 27                Show me the fastest route from X to Y
# 28          Can you recommend a charging station nearby
# 29                  Will it rain heavily in Delhi today
# 30            What is the temperature outisde right now
# 31                  Did I receive messages on Instagram
# 32              Are there any missed calls or app alert
# 33                 Play my favourite songs from Spotify
# 34                   Can you play some background music
# 35               Terminate pending bike software update
# 36                    Cancel bike system update process
# 37                     Begin bike software system upate
# 38              Please begin bike software system upate
# 39    Please check for available system updates for ...
# 40                   Please verify pending bike updates
# Name: Command, dtype: object

# %%
results=[]
for cmds in df_test['Command']:
    prediction = predict_class(cmds,tokenizer,model,max_sequence_length)
    if(prediction==0):
        print("Edge :", prediction)
        results.append('EDGE')
    elif(prediction==1):
        print("Cloud :", prediction)
        results.append('CLOUD')
    elif(prediction==2):
        print("Update :",prediction)
        results.append('UPDATE')
    elif(prediction==3):
        print("Miscellaneous :",prediction)
        results.append('MISCELLANEOUS')
    else:
        print("Dont know")
        
print(results)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Edge : 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Cloud : 1
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Update : 2
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Update : 2
# ['UPDATE', 'UPDATE', 'UPDATE', 'UPDATE', 'EDGE', 'UPDATE', 'UPDATE', 'UPDATE', 'UPDATE', 'CLOUD', 'EDGE', 'EDGE', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'EDGE', 'EDGE', 'EDGE', 'EDGE', 'EDGE', 'CLOUD', 'EDGE', 'EDGE', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'CLOUD', 'UPDATE', 'UPDATE', 'UPDATE', 'UPDATE', 'UPDATE', 'UPDATE']

# %%
#results

# %%
# Convert list to DataFrame
df_testResult = pd.DataFrame(results, columns=['Test_Result'])
#df_testResult

# %%
dfconcat_testResult= pd.concat([df_test['Command'],df_test['SubClass'], df_testResult['Test_Result']], axis=1)

# Convert values in 'SubClass' column to uppercase
dfconcat_testResult['SubClass'] = dfconcat_testResult['SubClass'].str.upper()

# Create 'TrueFalse' column based on conditions
dfconcat_testResult['TrueFalse'] = dfconcat_testResult['SubClass'] == dfconcat_testResult['Test_Result'].str.upper()

dfconcat_testResult
# Out:
#                                               Command SubClass Test_Result  \
# 0                             Please check for update   UPDATE      UPDATE
# 1                       Please show me current update   UPDATE      UPDATE
# 2                          please perform bike update   UPDATE      UPDATE
# 3                   please kindly perform bike update   UPDATE      UPDATE
# 4            will I reach hyderabad with current fuel     EDGE        EDGE
# 5                                    Check for update   UPDATE      UPDATE
# 6                              Show me current update   UPDATE      UPDATE
# 7                                 perform bike update   UPDATE      UPDATE
# 8                          kindly perform bike update   UPDATE      UPDATE
# 9   Kindly tell me  whether will I reach hyderabad...     EDGE       CLOUD
# 10          Is current fuel enough to reach Hyderabad     EDGE        EDGE
# 11                     Are my tyres pressure balanced     EDGE        EDGE
# 12               Show me the fastest route to kolkata    CLOUD       CLOUD
# 13                 Will it rain tomorrow in bangaluru    CLOUD       CLOUD
# 14                What is the weather status in delhi    CLOUD       CLOUD
# 15                      Play my playlist form spotify    CLOUD       CLOUD
# 16                                          Go to goa    CLOUD       CLOUD
# 17                                   Please go to goa    CLOUD       CLOUD
# 18                                     Take me to goa    CLOUD       CLOUD
# 19                   What is my current battery level     EDGE        EDGE
# 20                        Check my current fuel level     EDGE        EDGE
# 21                       Do I need to change the tyre     EDGE        EDGE
# 22                    Check tyre pressure and balance     EDGE        EDGE
# 23                 Check if tyre pressure is balanced     EDGE        EDGE
# 24                        what is current temperature    CLOUD       CLOUD
# 25            turn off the left indicator of the bike     EDGE        EDGE
# 26            turn on the right indicator of the bike     EDGE        EDGE
# 27              Show me the fastest route from X to Y    CLOUD       CLOUD
# 28        Can you recommend a charging station nearby    CLOUD       CLOUD
# 29                Will it rain heavily in Delhi today    CLOUD       CLOUD
# 30          What is the temperature outisde right now    CLOUD       CLOUD
# 31                Did I receive messages on Instagram    CLOUD       CLOUD
# 32            Are there any missed calls or app alert    CLOUD       CLOUD
# 33               Play my favourite songs from Spotify    CLOUD       CLOUD
# 34                 Can you play some background music    CLOUD       CLOUD
# 35             Terminate pending bike software update   UPDATE      UPDATE
# 36                  Cancel bike system update process   UPDATE      UPDATE
# 37                   Begin bike software system upate   UPDATE      UPDATE
# 38            Please begin bike software system upate   UPDATE      UPDATE
# 39  Please check for available system updates for ...   UPDATE      UPDATE
# 40                 Please verify pending bike updates   UPDATE      UPDATE
#
#     TrueFalse
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
# 5        True
# 6        True
# 7        True
# 8        True
# 9       False
# 10       True
# 11       True
# 12       True
# 13       True
# 14       True
# 15       True
# 16       True
# 17       True
# 18       True
# 19       True
# 20       True
# 21       True
# 22       True
# 23       True
# 24       True
# 25       True
# 26       True
# 27       True
# 28       True
# 29       True
# 30       True
# 31       True
# 32       True
# 33       True
# 34       True
# 35       True
# 36       True
# 37       True
# 38       True
# 39       True
# 40       True

# %%
#######################################################################################################################
############################################## Subclass Category ######################################################

# %%
# Set the random seeds for reproducibility
def set_seed(seed=1):
    random.seed(seed)
    np.random.seed(seed)
    tf.random.set_seed(seed)

# Optionally, if using GPU, configure GPU settings to avoid non-determinism
def configure_gpu_memory_growth():
    gpus = tf.config.experimental.list_physical_devices('GPU')
    if gpus:
        try:
            for gpu in gpus:
                tf.config.experimental.set_memory_growth(gpu, True)
        except RuntimeError as e:
            print(e)

# Call these functions at the start of your code to ensure reproducibility
set_seed(1)  # Setting the seed for reproducibility
configure_gpu_memory_growth()  # Optionally manage GPU memory growth

# %%
df_edge = df[df['Subclass'] == 'Edge']
df_cloud = df[df['Subclass'] == 'Cloud']
df_update = df[df['Subclass'] == 'Update']
df_miscellaneous = df[df['Subclass'] == 'Miscellaneous']
df_notneeded = df[df['Subclass'] == 'Not needed']

df_edge.reset_index(drop=True, inplace=True)
df_cloud.reset_index(drop=True, inplace=True)
df_update.reset_index(drop=True, inplace=True)
df_miscellaneous.reset_index(drop=True, inplace=True)
df_notneeded.reset_index(drop=True, inplace=True)

# %%
df_edge
# Save DataFrame to a CSV file
#df_edge.to_csv("df_edge.csv", index=False)
# Out:
#     Class Subclass SubclassCategory  \
# 0    Bike     Edge     Battery/Fuel
# 1    Bike     Edge     Battery/Fuel
# 2    Bike     Edge     Battery/Fuel
# 3    Bike     Edge     Battery/Fuel
# 4    Bike     Edge     Battery/Fuel
# ..    ...      ...              ...
# 546  Bike     Edge            Basic
# 547  Bike     Edge            Basic
# 548  Bike     Edge     Battery/Fuel
# 549  Bike     Edge     Battery/Fuel
# 550  Bike     Edge            Basic
#
#                                               Commands  \
# 0                    What is my current battery level?
# 1         How much range do I have left on my battery?
# 2       When was the last time my battery was charged?
# 3          How long until my battery is fully charged?
# 4    How long should I charge my vehicle for a suff...
# ..                                                 ...
# 546  Check for loose bolts in the bike's rear wheel...
# 547             Perform a bike clutch cable inspection
# 548           will I reach hyderabad with current fuel
# 549    Kindly will I reach hyderabad with current fuel
# 550  Activate bike's cruise control with speed limiter
#
#                                               Response  Label
# 0                                 Updating please wait      1
# 1                                 Updating please wait      1
# 2                                 Updating please wait      1
# 3                                 Updating please wait      1
# 4                                 Updating please wait      1
# ..                                                 ...    ...
# 546  Inspect and tighten any loose bolts in the rea...      1
# 547  Inspect the clutch cable for signs of wear and...      1
# 548   Processing your fuel related command please wait      1
# 549   Processing your fuel related command please wait      1
# 550  Utilize cruise control with speed limiter for ...      1
#
# [551 rows x 6 columns]

# %%
df_cloud
# Save DataFrame to a CSV file
#df_cloud.to_csv("df_cloud.csv", index=False)
# Out:
#     Class Subclass SubclassCategory                               Commands  \
# 0    Bike    Cloud      Songs/media                    Play "XYZ" by "ABC"
# 1    Bike    Cloud      Songs/media                 Play my favorite song.
# 2    Bike    Cloud      Songs/media                   Start playing music.
# 3    Bike    Cloud      Songs/media                   Shuffle my playlist.
# 4    Bike    Cloud      Songs/media                 Play the latest track.
# ..    ...      ...              ...                                    ...
# 443  Bike    Cloud     Traffic/Maps  Navigate to hyderbad/kolkata/banglore
# 444  Bike    Cloud          Weather                 Check weather forecast
# 445  Bike    Cloud      Songs/media                             Play music
# 446  Bike    Cloud     Traffic/Maps                    Take a scenic route
# 447  Bike    Cloud     Traffic/Maps              Check for traffic updates
#
#                                               Response  Label
# 0         Please wait, your request is been processed.      1
# 1         Please wait, your request is been processed.      1
# 2         Please wait, your request is been processed.      1
# 3         Please wait, your request is been processed.      1
# 4         Please wait, your request is been processed.      1
# ..                                                 ...    ...
# 443  You receive turn-by-turn directions to [destin...      1
# 444                 The weather forecast is [weather].      1
# 445                Your favorite music starts playing.      1
# 446            The navigation suggests a scenic route.      1
# 447        There are no traffic updates at the moment.      1
#
# [448 rows x 6 columns]

# %%
df_update
# Save DataFrame to a CSV file
#df_update.to_csv("df_update.csv", index=False)
# Out:
#     Class Subclass SubclassCategory  \
# 0    Bike   Update           Cancel
# 1    Bike   Update           Cancel
# 2    Bike   Update           Cancel
# 3    Bike   Update           Cancel
# 4    Bike   Update           Cancel
# ..    ...      ...              ...
# 314  Bike   Update            Check
# 315  Bike   Update            Check
# 316  Bike   Update            Check
# 317  Bike   Update            Check
# 318  Bike   Update            Check
#
#                                       Commands                 Response  Label
# 0           Abort pending bike firmware update     Aborting please wait      1
# 1             Abort pending bike system update     Aborting please wait      1
# 2               Abort software update for bike     Aborting please wait      1
# 3                  Cancel bike firmware update     Aborting please wait      1
# 4          Cancel bike software update process     Aborting please wait      1
# ..                                         ...                      ...    ...
# 314                  Check for current update   Processing your command      1
# 315        Check for current available update   Processing your command      1
# 316  Please check for current available update  Processing your command      1
# 317            Please check for current update  Processing your command      1
# 318                Check for available updates  Processing your command      1
#
# [319 rows x 6 columns]

# %%
df_miscellaneous
# Save DataFrame to a CSV file
#df_miscellaneous.to_csv("df_miscellaneous.csv", index=False)
# Out:
# Empty DataFrame
# Columns: [Class, Subclass, SubclassCategory, Commands, Response, Label]
# Index: []

# %%
df_notneeded
# Save DataFrame to a CSV file
#df_notneeded.to_csv("df_notneeded.csv", index=False)
# Out:
#         Class    Subclass SubclassCategory                  Commands  \
# 0        Bike  Not needed        Greetings                   Hi TVS!
# 1        Bike  Not needed        Greetings           Hello, Vehicle!
# 2        Bike  Not needed        Greetings             Good morning!
# 3        Bike  Not needed        Greetings           Good afternoon!
# 4        Bike  Not needed        Greetings             Good evening!
# ...       ...         ...              ...                       ...
# 1665  NonBike  Not needed               NC  Perform my pets marriage
# 1666  NonBike  Not needed               NC  Perform my dogs marriage
# 1667  NonBike  Not needed               NC      check blood pressure
# 1668  NonBike  Not needed               NC   check balloon pressure
# 1669  NonBike  Not needed               NC            check my books
#
#                        Response  Label
# 0                            Hi      1
# 1                         Hello      1
# 2                  Good morning      1
# 3                Good afternoon      1
# 4                  Good evening      1
# ...                         ...    ...
# 1665  It is a  non bike command      0
# 1666  It is a  non bike command      0
# 1667  It is a  non bike command      0
# 1668  It is a  non bike command      0
# 1669  It is a  non bike command      0
#
# [1670 rows x 6 columns]

# %%
# Function to predict the class of a command
def predict_class(command,tokenizer,model,max_sequence_length):
    sequence = tokenizer.texts_to_sequences([command])
    padded_sequence = pad_sequences(sequence, maxlen=max_sequence_length, padding='post')
    prediction = model.predict(padded_sequence)
    predicted_class_index = np.argmax(prediction)
    return predicted_class_index

# %%
def train_model_subClassCategory(df, filename, subclassCat):
    
    # Preprocessing
    X = df['Commands']
    df = df.copy()
    df['Subclass_Label_Category'], _ = pd.factorize(df['SubclassCategory'])
    
    # Save DataFrame to a CSV file
    df.to_csv(filename, index=False)

    y = df['Subclass_Label_Category']
    
    # Tokenize the text data
    tokenizer = Tokenizer()
    tokenizer.fit_on_texts(X)
    X_sequences = tokenizer.texts_to_sequences(X)
    
    # Padding sequences to make them of equal length
    max_sequence_length = max([len(seq) for seq in X_sequences])
    X_padded = pad_sequences(X_sequences, maxlen=max_sequence_length, padding='post')

    # Convert labels to one-hot encoding
    y_encoded = to_categorical(y)
    
    # Split the dataset into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X_padded, y_encoded, test_size=0.2, random_state=42)
    
    # Define the RNN model for multiclass classification
    num_classes = len(np.unique(y))  # Number of unique classes
    model = Sequential()
    model.add(Embedding(input_dim=len(tokenizer.word_index)+1, output_dim=100, input_length=max_sequence_length))
    model.add(LSTM(256, return_sequences=True))
    model.add(LSTM(128, return_sequences=True))
    model.add(LSTM(64, return_sequences=True))
    model.add(LSTM(32))
    model.add(Dense(num_classes, activation='softmax'))  # Softmax activation for multiclass classification

    # Compile the model with categorical cross-entropy loss
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=15, batch_size=64, validation_data=(X_test, y_test))
    
    # Save the model and tokenizer
    joblib.dump(model, './RNN_save_model/LSTM/'+subclassCat+'/RNN_Multiclass_SubclassCategory.joblib')
    joblib.dump(tokenizer, './RNN_save_model/LSTM/'+subclassCat+'/tokenizer.joblib')
    joblib.dump(max_sequence_length, './RNN_save_model/LSTM/'+subclassCat+'/max_sequence_length.joblib')
    
    # Evaluate the model
    loss, accuracy = model.evaluate(X_test, y_test)
    print("Test Loss:", loss)
    print("Test Accuracy:", accuracy)

    # Predict on test data
    y_pred_prob = model.predict(X_test)
    y_pred = np.argmax(y_pred_prob, axis=1)
    y_test_actual = np.argmax(y_test, axis=1)

    # Classification report (Precision, Recall, F1-Score)
    print("\nClassification Report:\n", classification_report(y_test_actual, y_pred))

    # Confusion matrix
    cm = confusion_matrix(y_test_actual, y_pred)
    plt.figure(figsize=(10, 7))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('Actual')
    plt.show()

    # Calculate Precision, Recall, F1-Score
    precision, recall, f1, _ = precision_recall_fscore_support(y_test_actual, y_pred, average='macro')
    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")

    # ROC-AUC Curve (One-vs-Rest)
    y_test_bin = label_binarize(y_test_actual, classes=np.arange(num_classes))  # Binarize labels for ROC-AUC
    roc_auc = roc_auc_score(y_test_bin, y_pred_prob, multi_class='ovr')
    print(f"ROC-AUC Score: {roc_auc:.2f}")

    # Plot ROC curve for each class
    fpr = dict()
    tpr = dict()
    for i in range(num_classes):
        fpr[i], tpr[i], _ = roc_curve(y_test_bin[:, i], y_pred_prob[:, i])
    
    plt.figure(figsize=(10, 7))
    for i in range(num_classes):
        plt.plot(fpr[i], tpr[i], label=f'Class {i} (AUC = {roc_auc:.2f})')
    
    plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve - Multiclass Classification')
    plt.legend(loc="lower right")
    plt.show()

    # Precision-Recall Curve for each class
    precision_dict = dict()
    recall_dict = dict()

    for i in range(num_classes):
        precision_dict[i], recall_dict[i], _ = precision_recall_curve(y_test_bin[:, i], y_pred_prob[:, i])

    plt.figure(figsize=(10, 7))
    for i in range(num_classes):
        plt.plot(recall_dict[i], precision_dict[i], label=f'Class {i}')
    
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.title('Precision-Recall Curve - Multiclass Classification')
    plt.legend(loc="lower left")
    plt.show()

    # Plot both training and testing accuracy curves
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Testing Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.ylim([0, 1])
    plt.legend()
    plt.show()

    return model, tokenizer, max_sequence_length

# %%
######################################################EDGE########################################################
filename="df_edge.csv"
subclasscat="EDGE"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_edge,filename,subclasscat)
# Out:
# Epoch 1/15
# C:\Users\anirban.saha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 6s 182ms/step - accuracy: 0.4267 - loss: 1.0577 - val_accuracy: 0.4414 - val_loss: 1.0833
# Epoch 2/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - accuracy: 0.5825 - loss: 0.8985 - val_accuracy: 0.7027 - val_loss: 0.6871
# Epoch 3/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.7604 - loss: 0.5488 - val_accuracy: 0.7568 - val_loss: 0.5712
# Epoch 4/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 84ms/step - accuracy: 0.7230 - loss: 0.5268 - val_accuracy: 0.7568 - val_loss: 0.5405
# Epoch 5/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.7735 - loss: 0.4966 - val_accuracy: 0.7568 - val_loss: 0.5252
# Epoch 6/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.7798 - loss: 0.4526 - val_accuracy: 0.7477 - val_loss: 0.5605
# Epoch 7/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.7851 - loss: 0.4245 - val_accuracy: 0.7477 - val_loss: 0.6438
# Epoch 8/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.8933 - loss: 0.3558 - val_accuracy: 0.8649 - val_loss: 0.4990
# Epoch 9/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.9448 - loss: 0.2381 - val_accuracy: 0.8919 - val_loss: 0.4314
# Epoch 10/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.9306 - loss: 0.2618 - val_accuracy: 0.9009 - val_loss: 0.3873
# Epoch 11/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - accuracy: 0.9545 - loss: 0.1920 - val_accuracy: 0.8829 - val_loss: 0.4861
# Epoch 12/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.9541 - loss: 0.1867 - val_accuracy: 0.9189 - val_loss: 0.3489
# Epoch 13/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.9521 - loss: 0.1957 - val_accuracy: 0.9279 - val_loss: 0.2831
# Epoch 14/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - accuracy: 0.9600 - loss: 0.1745 - val_accuracy: 0.8559 - val_loss: 0.5044
# Epoch 15/15
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.9557 - loss: 0.1671 - val_accuracy: 0.8829 - val_loss: 0.4165
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8782 - loss: 0.4646
# Test Loss: 0.41648322343826294
# Test Accuracy: 0.8828828930854797
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 163ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.77      0.86        35
#            1       0.72      0.85      0.78        27
#            2       0.94      0.98      0.96        49
#
#     accuracy                           0.88       111
#    macro avg       0.87      0.87      0.87       111
# weighted avg       0.89      0.88      0.88       111
# Precision: 0.87
# Recall: 0.87
# F1 Score: 0.87
# ROC-AUC Score: 0.95

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Edge -> Battery Fuel:", prediction)
elif(prediction==1):
    print("Edge -> Tires:", prediction)
elif(prediction==2):
    print("Edge -> Basic :",prediction)
else:
    print("Dont know")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 369ms/step
# Edge -> Tires: 1

# %%
########################################################CLOUD###############################################
filename="df_cloud.csv"
subclasscat="CLOUD"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_cloud,filename,subclasscat)
# Out:
# Epoch 1/15
# C:\Users\anirban.saha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 7s 251ms/step - accuracy: 0.2796 - loss: 1.3868 - val_accuracy: 0.3333 - val_loss: 1.3861
# Epoch 2/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.2996 - loss: 1.3808 - val_accuracy: 0.3333 - val_loss: 1.3491
# Epoch 3/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - accuracy: 0.3947 - loss: 1.2485 - val_accuracy: 0.4333 - val_loss: 1.2425
# Epoch 4/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - accuracy: 0.4795 - loss: 1.0144 - val_accuracy: 0.5111 - val_loss: 0.9756
# Epoch 5/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - accuracy: 0.5445 - loss: 0.8910 - val_accuracy: 0.6111 - val_loss: 0.9094
# Epoch 6/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - accuracy: 0.6537 - loss: 0.6978 - val_accuracy: 0.7111 - val_loss: 0.7354
# Epoch 7/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - accuracy: 0.7202 - loss: 0.4840 - val_accuracy: 0.6333 - val_loss: 0.8391
# Epoch 8/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.7694 - loss: 0.5272 - val_accuracy: 0.7000 - val_loss: 0.8301
# Epoch 9/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.7067 - loss: 0.5370 - val_accuracy: 0.6444 - val_loss: 0.6026
# Epoch 10/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - accuracy: 0.7832 - loss: 0.3976 - val_accuracy: 0.6333 - val_loss: 0.7969
# Epoch 11/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - accuracy: 0.7675 - loss: 0.4218 - val_accuracy: 0.7111 - val_loss: 0.8552
# Epoch 12/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - accuracy: 0.7364 - loss: 0.3962 - val_accuracy: 0.6889 - val_loss: 0.8497
# Epoch 13/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - accuracy: 0.6923 - loss: 0.5459 - val_accuracy: 0.7333 - val_loss: 0.7004
# Epoch 14/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - accuracy: 0.6879 - loss: 0.6171 - val_accuracy: 0.6889 - val_loss: 1.0067
# Epoch 15/15
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - accuracy: 0.6663 - loss: 0.6400 - val_accuracy: 0.6889 - val_loss: 0.5426
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.6804 - loss: 0.5255
# Test Loss: 0.5426144003868103
# Test Accuracy: 0.6888889074325562
# WARNING:tensorflow:5 out of the last 48 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026B2B367EC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/3 ━━━━━━━━━━━━━━━━━━━━ 1s 561ms/stepWARNING:tensorflow:6 out of the last 50 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000026B2B367EC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.67      0.22      0.33        27
#            1       0.39      0.70      0.50        20
#            2       0.87      1.00      0.93        13
#            3       0.97      0.97      0.97        30
#
#     accuracy                           0.69        90
#    macro avg       0.72      0.72      0.68        90
# weighted avg       0.73      0.69      0.67        90
# Precision: 0.72
# Recall: 0.72
# F1 Score: 0.68
# ROC-AUC Score: 0.89

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Cloud -> Song Media:", prediction)
elif(prediction==1):
    print("Cloud -> News Notification:", prediction)
elif(prediction==2):
    print("Cloud -> Weather :",prediction)
elif(prediction==3):
    print("Cloud -> Traffic Maps :",prediction)
else:
    print("Dont know")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# Cloud -> News Notification: 1

# %%
###########################################Update#################################################
filename="df_update.csv"
subclasscat="UPDATE"
model,tokenizer, max_sequence_length=train_model_subClassCategory(df_update,filename,subclasscat)
# Out:
# Epoch 1/15
# C:\Users\anirban.saha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 200ms/step - accuracy: 0.3611 - loss: 1.0949 - val_accuracy: 0.8281 - val_loss: 1.0709
# Epoch 2/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - accuracy: 0.8414 - loss: 1.0251 - val_accuracy: 0.5938 - val_loss: 0.8423
# Epoch 3/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.7215 - loss: 0.7160 - val_accuracy: 1.0000 - val_loss: 0.5489
# Epoch 4/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9343 - loss: 0.4614 - val_accuracy: 0.8438 - val_loss: 0.5109
# Epoch 5/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9181 - loss: 0.3755 - val_accuracy: 1.0000 - val_loss: 0.1489
# Epoch 6/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9687 - loss: 0.1593 - val_accuracy: 1.0000 - val_loss: 0.0691
# Epoch 7/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - accuracy: 0.9875 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0365
# Epoch 8/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - accuracy: 0.9943 - loss: 0.0495 - val_accuracy: 1.0000 - val_loss: 0.0285
# Epoch 9/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9901 - loss: 0.0484 - val_accuracy: 0.9844 - val_loss: 0.0807
# Epoch 10/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9932 - loss: 0.0433 - val_accuracy: 0.9844 - val_loss: 0.0957
# Epoch 11/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 1.0000 - loss: 0.0187 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 12/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9984 - loss: 0.0174 - val_accuracy: 0.9688 - val_loss: 0.1212
# Epoch 13/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9917 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0127
# Epoch 14/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - accuracy: 0.9974 - loss: 0.0244 - val_accuracy: 0.9844 - val_loss: 0.1002
# Epoch 15/15
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.9906 - loss: 0.0515 - val_accuracy: 0.9844 - val_loss: 0.0903
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9792 - loss: 0.1177
# Test Loss: 0.09033103287220001
# Test Accuracy: 0.984375
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      1.00      0.98        20
#            1       1.00      0.96      0.98        28
#            2       1.00      1.00      1.00        16
#
#     accuracy                           0.98        64
#    macro avg       0.98      0.99      0.99        64
# weighted avg       0.99      0.98      0.98        64
# Precision: 0.98
# Recall: 0.99
# F1 Score: 0.99
# ROC-AUC Score: 1.00

# %%
# Load the model from and tokenizer
model = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/RNN_Multiclass_SubclassCategory.joblib')
tokenizer = joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/tokenizer.joblib')
max_sequence_length=joblib.load('./RNN_save_model/LSTM/'+subclasscat+'/max_sequence_length.joblib')

# %%
# Example usage:
command = input("Enter a command: ")
print(command)
prediction = predict_class(command, tokenizer,model, max_sequence_length)
if(prediction==0):
    print("Update -> Cancel:", prediction)
elif(prediction==1):
    print("Update -> Perform:", prediction)
elif(prediction==2):
    print("Update -> Check:",prediction)
else:
    print("Dont know")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step
# Update -> Cancel: 0
